# %% [markdown]
# <center> <img src="http://oci02.img.iteso.mx/identidad_de_instancia_2018/ITESO/Logos%20ITESO/Logo-ITESO-Principal.jpg" align="center" width="960" height="480"/> </center>

# %% [markdown]
# <center><font color=#555555><font size=6> MAF1731 - Microstructure and Trading Systems </font> <br> <br>
#
# <center><font color=#555555><font size=5> B.Eng Financial Engineering </font> <br> <br> <br> <br>
#
# <center><font color='navy'><font size=6> I.F. Barragán Vázquez Lizbeth Alejandra </font> <br> <br>
#
# <center> <font color= #555555> <font size = 4> November 09th 2021 </a> | <font color= #555555> <font size = 4> Repository: <a href='https://github.com/labv98/Lab1_LABV.git'>Link</a></font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# <center> <font color= #555555> <font size = 6> Laboratory 1 </font> <br> <br> <font color= #555555> <font size = 5> Inversión Activa y Pasiva con POO  </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# <br>

# %% [markdown]
# <font color= 'navy'> <font size = 4> Abstract </font>

# %% [markdown]
# <font size = 3>  En el presente laboratorio se encuentra el análisis realizado a una setie de ETF's que fueron dados por el profesor de la materia de Microestructuras y Sistemas de Trading con la finalidad de contrastarlos a los precios descargados de un portafolio ficticio creado. Donde en teoría se cuenta con un saldo de $1,000,000 mismo que será utilizado en las inversiones.
#
# <font size = 3> La finalidad de esto es observar el comportamiento de las inversiones bajo dos esquemas:
# Inversión Pasiva e Inversión Activa con los escenarios de antes y durante la pandemia suscitada en 2020 de COVID. El objetivo es observar el comportamiento de nuestro capital respecto a los rendimientos que se pudieran tener.

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= 'navy'> <font size = 6> 1. Introduction </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# En el presente documento se muestran los reflejos creados en base a una serie de funciones que nos analizan el comportamiento de las inversiones creadas con un portafolio ficticio de 1 millón de pesos.
#
# Estás inversiones se encuentran plasmadas bajo dos esquemas:
#
# **Inversión Pasiva**
#
# Podemos decir que la inversión pasiva es la compra de certificados de inversión o unidades de participación en un fondo que administra una cartera de inversiones de una forma conservadora. Dicho de otra manera, es aquel tipo de inversión que no busca ir más allá de los rendimientos estándar y medios del mercado, sino que trata de seguir el movimiento establecido por la corriente bursátil sin correr riesgos. Este tipo de inversión está muy recomendado y es utilizado principalmente por los inversores inexpertos que apenas se están iniciando en el mercado bursátil. Una de sus características principales es su bajo rendimiento, directamente proporcional con su nivel de riesgo.
#
# La ventaja de este tipo de inversión es, sobre todo, que no requiere tanto tiempo para seleccionar instrumentos.
#
# **Inversión Activa**
#
# La inversión activa, se centra en obtener un mejor rendimiento del mercado en comparación con un índice medio de referencia en particular.
# En el mercado de valores los precios de los activos de inversión suben y bajan continuamente. Sin embargo, en la inversión activa, los administradores de cartera no siguen los movimientos diarios de los precios de los índices. Sus objetivos siempre van más allá, se centran en buscar acciones cuyo valor accionario sea susceptible de subir en el futuro próximo, ya sea que el mercado de valores en su conjunto suba o baje.
#
# La toma de decisiones en la inversión activa implica una investigación, un análisis y una experiencia mucho más profundas para saber cuándo activar o desactivar una acción, un bono o cualquier activo en particular.
#
# Como podemos apreciar ambas inversiones son diferentes. Sin embargo, el objetivo es analizar cuál resulta mejor para el inversionista. Asimismo observaremos los cambios que se suscitan a raíz de la pandemia de COVID-19 y verificaremos la teoría de la caída en los mercados en aquél momento.

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= 'navy'> 2. Install/Load Packages and Depedencies </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# ## <font color= 'navy'> 2.2 Python Packages </font> <font color= #555555>

# %% [markdown]
# Para pode correr el presente notebook, será necesario haber instalado o ya tener el archivo _requirements.txt_ que presenta lo siguiente:

# %% [markdown]
# - pandas>=1.1.1
# - numpy>=1.19.1
# - jupyter>=1.0.0
# - chart_studio>=1.1
# - plotly>=4.14
# - yahoofinance

# %% [markdown]
# <br>

# %% [markdown]
# ## <font color= 'navy'> 2.3 Files Dependencies </font> <font color= #555555>

# %% [markdown]
# Las dependencias necesarias para poder correr el notebook son:

# %% [markdown]
# - files/NAFTRAC.csv : Precios ETF por fecha
# - functions.py

# %%
from functions import *

# %%
# Por si existe algún warning
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= 'navy'> 3. Data Description </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# #### <font color= 'navy'> <center> 3.1 Lectura de files </font>

# %% [markdown]
# > En este apartado se encuentra la lectura de los archivos provenientes desde la carpeta 'files', donde se encuentran los archivos brindados por el profesor de la materia de Micreoestructura y Sistemas de Trading mismos que serán contrarrestados a los precios que se descargan desde Yahoo Finance.

# %%
FilesHandler().read_df().head(10)
# Out:
#                                          Nombre  Peso (%)  Precio
# Ticker
# FEMSAUBD.MX          FOMENTO ECONOMICO MEXICANO    0.1270  176.47
# AMXL.MX                         AMERICA MOVIL L    0.1237   13.68
# GFNORTEO.MX                 GPO FINANCE BANORTE    0.1040   93.15
# WALMEX.MX                   WALMART DE MEXICO V    0.0953   50.34
# CEMEXCPO.MX                           CEMEX CPO    0.0591   10.47
# GMEXICOB.MX                      GRUPO MEXICO B    0.0582   41.98
# TLEVISACPO.MX                    GRUPO TELEVISA    0.0472   55.65
# BIMBOA.MX                         GRUPO BIMBO A    0.0284      39
# ALFAA.MX                                 ALFA A    0.0240   20.46
# GFINBURO.MX    GRUPO FINANCIERO INBURSA SRIES O    0.0239   27.42

# %% [markdown]
# Este primer DataFrame muestra la lectura de los archivos que se mencionaron pero se hizo de una manera concatenada, por lo que es la lectura de cada archivo en un mismo DF.

# %% [markdown]
# #### <font color= 'navy'> <center> 3.2 Descarga de datos </font>

# %%
tickers, data_down, data_close = FilesHandler().tickers()
data_close.head(5)
# Out:
# [*********************100%***********************]  40 of 40 completed
#                  AC.MX   ALFAA.MX  ALPEKA.MX   ALSEA.MX    AMXL.MX  \
# Date
# 2018-01-31  135.050003  23.360001  26.860001  60.880001  17.440001
# 2018-02-01  137.139999  23.730000  27.370001  61.490002  17.639999
# 2018-02-02  138.720001  23.160000  27.490000  62.110001  17.420000
# 2018-02-06  134.059998  22.580000  26.600000  61.230000  17.190001
# 2018-02-07  134.649994  22.629999  26.150000  62.139999  16.879999
#
#               ASURB.MX  BBAJIOO.MX  BIMBOA.MX  BOLSAA.MX  CEMEXCPO.MX  ...  \
# Date                                                                   ...
# 2018-01-31  362.220001   39.330002  45.400002  35.619999        15.48  ...
# 2018-02-01  365.390015   39.610001  46.169998  35.950001        15.34  ...
# 2018-02-02  362.420013   39.900002  46.310001  35.610001        15.21  ...
# 2018-02-06  351.329987   39.330002  46.009998  35.439999        14.92  ...
# 2018-02-07  343.559998   39.820000  45.779999  33.869999        14.70  ...
#
#              ORBIA.MX  PE&OLES.MX   PINFRA.MX       Q.MX       RA.MX  \
# Date
# 2018-01-31  52.750000  431.350006  190.779999  46.500000  115.919998
# 2018-02-01  53.450001  434.600006  190.119995  46.500000  115.370003
# 2018-02-02  53.439999  412.750000  189.339996  47.380001  116.070000
# 2018-02-06  51.849998  399.640015  185.589996  46.560001  115.980003
# 2018-02-07  51.680000  411.950012  186.220001  45.750000  115.360001
#
#             SITESB-1.MX  TLEVISACPO.MX   VESTA.MX  VOLARA.MX  WALMEX.MX
# Date
# 2018-01-31        13.97      77.019997  25.639999      15.93  46.639999
# 2018-02-01        13.87      76.949997  25.629999      15.81  46.130001
# 2018-02-02        13.42      76.550003  25.700001      15.66  46.639999
# 2018-02-06        13.09      74.480003  25.049999      15.15  44.610001
# 2018-02-07        13.14      73.879997  25.049999      15.34  45.560001
#
# [5 rows x 40 columns]

# %% [markdown]
# En este segundo paso encontramos el DataFrame que incluye los precios de cierre de los activos que se encuentran en análisis.

# %% [markdown]
# #### <font color= 'navy'> <center> 3.3 Posturas y capital </font>

# %%
data_fin = FilesHandler().f_data_fin()
data_fin
# Out:
# [*********************100%***********************]  40 of 40 completed
#                Peso (%)     Precios  Titulos    Capital    Postura  Comisiones
# Ticker
# AC.MX            0.0175  135.050003    129.0   17443.23   17421.45       21.78
# ALFAA.MX         0.0268   23.360001   1145.0   26780.63   26747.20       33.43
# ALPEKA.MX        0.0032   26.860001    118.0    3173.44    3169.48        3.96
# ALSEA.MX         0.0083   60.880001    136.0    8290.03    8279.68       10.35
# AMXL.MX          0.1331   17.440001   7622.0  133093.84  132927.68      166.16
# ASURB.MX         0.0244  362.220001     67.0   24299.08   24268.74       30.34
# BIMBOA.MX        0.0178   45.400002    391.0   17773.59   17751.40       22.19
# CEMEXCPO.MX      0.0744   15.480000   4800.0   74396.88   74304.00       92.88
# CUERVO.MX        0.0062   33.860001    182.0    6170.22    6162.52        7.70
# ELEKTRA.MX       0.0136  672.390015     20.0   13464.61   13447.80       16.81
# FEMSAUBD.MX      0.1269  181.520004    698.0  126859.34  126700.96      158.38
# GAPB.MX          0.0251  194.589996    128.0   24938.65   24907.52       31.13
# GCARSOA1.MX      0.0090   69.820000    128.0    8948.13    8936.96       11.17
# GENTERA.MX       0.0055   16.870001    325.0    5489.60    5482.75        6.85
# GFINBURO.MX      0.0174   32.930000    527.0   17375.80   17354.11       21.69
# GFNORTEO.MX      0.0951  119.580002    794.0   95065.20   94946.52      118.68
# RA.MX            0.0042  115.919998     36.0    4178.34    4173.12        5.22
# GMEXICOB.MX      0.0754   65.980003   1141.0   75377.29   75283.18       94.10
# GRUMAB.MX        0.0154  222.300003     69.0   15357.87   15338.70       19.17
# IENOVA.MX        0.0169   97.010002    173.0   16803.71   16782.73       20.98
# KIMBERA.MX       0.0163   34.950001    465.0   16272.07   16251.75       20.31
# LABB.MX          0.0043   20.450001    210.0    4299.87    4294.50        5.37
# LALAB.MX         0.0049   29.770000    164.0    4888.38    4882.28        6.10
# LIVEPOLC-1.MX    0.0087  137.759995     63.0    8689.73    8678.88       10.85
# MEGACPO.MX       0.0084   85.160004     98.0    8356.11    8345.68       10.43
# ORBIA.MX         0.0177   52.750000    335.0   17693.34   17671.25       22.09
# NEMAKA.MX        0.0030   15.540000    192.0    2987.41    2983.68        3.73
# OMAB.MX          0.0099   94.989998    104.0    9891.31    9878.96       12.35
# PE&OLES.MX       0.0126  431.350006     29.0   12524.79   12509.15       15.64
# PINFRA.MX        0.0135  190.779999     70.0   13371.29   13354.60       16.69
# TLEVISACPO.MX    0.0621   77.019997    805.0   62078.60   62001.10       77.50
# VOLARA.MX        0.0046   15.930000    288.0    4593.57    4587.84        5.73
# WALMEX.MX        0.0760   46.639999   1627.0   75978.13   75883.28       94.85

# %% [markdown]
# Finalmente dentro de este DataFrame encontramos el ticker correspondiente al portafolio creado, su respectivo peso, precio, título, capital depositado, la postura y las comisiones correspondientes. Es en este momento donde se contrastó el primer archivo proveniente de files con los precios que descargamos con anterioridad de YahooFinance.

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= 'navy'> 4. Inversión Pasiva  </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# > En este apartado encontramos la inversión pasiva, que como ya se vio en la introducción de este laboratorio se trata de una inversión con menor riesgo. Se nota e un periodo comprendido entre el 31 de enero de 2018 hasta el 29 de octubre de 2021.

# %%
PassiveInvestment().inv_pasiva()
# Out:
# [*********************100%***********************]  40 of 40 completed
# [*********************100%***********************]  40 of 40 completed
#         Fecha      Capital  Rendimiento  Rendimiento Acumulado
# 0  2018-01-31  998704.0698       0.0000                 0.0000
# 1  2018-02-28  943229.3763      -0.0555                -0.0555
# 2  2018-03-28  918804.2526      -0.0259                -0.0800
# 3  2018-04-30  961670.5391       0.0467                -0.0371
# 4  2018-05-31  890398.9860      -0.0741                -0.1084
# 5  2018-06-29  949776.2854       0.0667                -0.0490
# 6  2018-07-31  985690.3577       0.0378                -0.0130
# 7  2018-08-31  984326.2953      -0.0014                -0.0144
# 8  2018-09-28  983378.3309      -0.0010                -0.0153
# 9  2018-10-31  878719.8045      -0.1064                -0.1201
# 10 2018-11-30  837984.8126      -0.0464                -0.1609
# 11 2018-12-31  835686.5961      -0.0027                -0.1632
# 12 2019-01-31  880290.8701       0.0534                -0.1186
# 13 2019-02-28  858646.0049      -0.0246                -0.1402
# 14 2019-03-29  865418.3890       0.0079                -0.1335
# 15 2019-04-30  887933.3025       0.0260                -0.1109
# 16 2019-05-31  854797.7941      -0.0373                -0.1441
# 17 2019-06-28  861685.1159       0.0081                -0.1372
# 18 2019-07-31  821967.9450      -0.0461                -0.1770
# 19 2019-08-30  856825.1160       0.0424                -0.1421
# 20 2019-09-30  852199.5119      -0.0054                -0.1467
# 21 2019-10-31  873111.6338       0.0245                -0.1258
# 22 2019-11-29  863192.3496      -0.0114                -0.1357
# 23 2019-12-31  878660.7284       0.0179                -0.1202
# 24 2020-01-31  888097.4249       0.0107                -0.1108
# 25 2020-02-28  832123.1706      -0.0630                -0.1668
# 26 2020-03-31  702007.1528      -0.1564                -0.2971
# 27 2020-04-30  743676.7133       0.0594                -0.2554
# 28 2020-05-29  736984.5738      -0.0090                -0.2621
# 29 2020-06-30  766571.8564       0.0401                -0.2324
# 30 2020-07-31  753400.8759      -0.0172                -0.2456
# 31 2020-08-31  751501.6346      -0.0025                -0.2475
# 32 2020-09-30  761563.5420       0.0134                -0.2374
# 33 2020-10-30  755095.7324      -0.0085                -0.2439
# 34 2020-11-30  851743.0108       0.1280                -0.1472
# 35 2020-12-31  894110.2533       0.0497                -0.1047
# 36 2021-01-29  872751.3343      -0.0239                -0.1261
# 37 2021-02-26  909494.4098       0.0421                -0.0893
# 38 2021-03-31  959550.2086       0.0550                -0.0392
# 39 2021-04-30  975310.3997       0.0164                -0.0234
# 40 2021-05-31 1031894.6234       0.0580                 0.0332
# 41 2021-06-30 1021192.2505      -0.0104                 0.0225
# 42 2021-07-30 1033255.3226       0.0118                 0.0346
# 43 2021-08-31 1077603.3429       0.0429                 0.0790
# 44 2021-09-30 1040811.8527      -0.0341                 0.0422
# 45 2021-10-29 1027350.0860      -0.0129                 0.0287

# %% [markdown]
# En este DataFrame encontramos la inversión pasiva en el periodo completo. Por lo que, se observa que después de una caída en los rendimientos acumulados hasta el 30 de abril, el inversionista se recupera y posterior a esa fecha sus rendimientos acumulados comienzan a ser positivos.

# %% [markdown]
# #### <font color= 'navy'> <center> 4.1 Antes de pandemia </font>

# %%
PassiveInvestment().ant_pan()
# Out:
# [*********************100%***********************]  40 of 40 completed
# [*********************100%***********************]  40 of 40 completed
#         Fecha     Capital  Rendimiento  Rendimiento Acumulado
# 0  2018-01-31 998704.0698       0.0000                 0.0000
# 1  2018-02-28 943229.3763      -0.0555                -0.0555
# 2  2018-03-28 918804.2526      -0.0259                -0.0800
# 3  2018-04-30 961670.5391       0.0467                -0.0371
# 4  2018-05-31 890398.9860      -0.0741                -0.1084
# 5  2018-06-29 949776.2854       0.0667                -0.0490
# 6  2018-07-31 985690.3577       0.0378                -0.0130
# 7  2018-08-31 984326.2953      -0.0014                -0.0144
# 8  2018-09-28 983378.3309      -0.0010                -0.0153
# 9  2018-10-31 878719.8045      -0.1064                -0.1201
# 10 2018-11-30 837984.8126      -0.0464                -0.1609
# 11 2018-12-31 835686.5961      -0.0027                -0.1632
# 12 2019-01-31 880290.8701       0.0534                -0.1186
# 13 2019-02-28 858646.0049      -0.0246                -0.1402
# 14 2019-03-29 865418.3890       0.0079                -0.1335
# 15 2019-04-30 887933.3025       0.0260                -0.1109
# 16 2019-05-31 854797.7941      -0.0373                -0.1441
# 17 2019-06-28 861685.1159       0.0081                -0.1372
# 18 2019-07-31 821967.9450      -0.0461                -0.1770
# 19 2019-08-30 856825.1160       0.0424                -0.1421
# 20 2019-09-30 852199.5119      -0.0054                -0.1467
# 21 2019-10-31 873111.6338       0.0245                -0.1258
# 22 2019-11-29 863192.3496      -0.0114                -0.1357
# 23 2019-12-31 878660.7284       0.0179                -0.1202
# 24 2020-01-31 888097.4249       0.0107                -0.1108

# %% [markdown]
# Se nota como para el "antes de pandemia" se tienen casi puros rendimientos acumulados negativos, esto nos indica como a nuestro inversionista no le funcionaría este esquema.

# %% [markdown]
# #### <font color= 'navy'> <center> 4.2 Durante pandemia </font>

# %%
PassiveInvestment().dur_pan()
# Out:
# [*********************100%***********************]  40 of 40 completed
# [*********************100%***********************]  40 of 40 completed
#         Fecha      Capital  Rendimiento  Rendimiento Acumulado
# 24 2020-01-31  888097.4249       0.0107                 0.0107
# 25 2020-02-28  832123.1706      -0.0630                -0.0523
# 26 2020-03-31  702007.1528      -0.1564                -0.2087
# 27 2020-04-30  743676.7133       0.0594                -0.1493
# 28 2020-05-29  736984.5738      -0.0090                -0.1583
# 29 2020-06-30  766571.8564       0.0401                -0.1181
# 30 2020-07-31  753400.8759      -0.0172                -0.1353
# 31 2020-08-31  751501.6346      -0.0025                -0.1379
# 32 2020-09-30  761563.5420       0.0134                -0.1245
# 33 2020-10-30  755095.7324      -0.0085                -0.1330
# 34 2020-11-30  851743.0108       0.1280                -0.0050
# 35 2020-12-31  894110.2533       0.0497                 0.0448
# 36 2021-01-29  872751.3343      -0.0239                 0.0209
# 37 2021-02-26  909494.4098       0.0421                 0.0630
# 38 2021-03-31  959550.2086       0.0550                 0.1180
# 39 2021-04-30  975310.3997       0.0164                 0.1345
# 40 2021-05-31 1031894.6234       0.0580                 0.1925
# 41 2021-06-30 1021192.2505      -0.0104                 0.1821
# 42 2021-07-30 1033255.3226       0.0118                 0.1939
# 43 2021-08-31 1077603.3429       0.0429                 0.2368
# 44 2021-09-30 1040811.8527      -0.0341                 0.2027
# 45 2021-10-29 1027350.0860      -0.0129                 0.1898

# %% [markdown]
# Se nota como para el durante pandemia se poseen mejores rendimientos. Pero si lo analizamos a profundidad vemos como en lo más fuerte de la pandemia los rendimientos y la caída del capital en el portafolio es realmente preocupante. Sin embargo, a partir del 31 de diciembre de 2020 hasta el momento se observa una mejoría significativa hecho que se puede atribuir a que ya se especulaba sobre las vacunas por lo que la población se relajó y las condiciones de los mercados volvieron a tornar su camino anterior.

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= 'navy'> 5. Inversión Activa  </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %%
# DELETE THIS CELL IN YOUR FILE

# Another particular process that is relevant for the work. Normally, you include between 2 and 5 at the most.

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= #6B6B6B> <font size = 6> 5. Results </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %%
# DELETE THIS CELL IN YOUR FILE

# In here you present the general results, and also, a discussion of such results.

# %% [markdown]
# <br>

# %% [markdown]
# ## <font color= #6B6B6B> 5.1 Results of first processes </font>

# %%
# DELETE THIS CELL IN YOUR FILE

# Separate your results according to the main processes you are working on

# %% [markdown]
# <br>

# %% [markdown]
# ## <font color= #6B6B6B> 5.2 Results of another proces </font>

# %%
# DELETE THIS CELL IN YOUR FILE

# You can have several processes with which you are obtaining the results you need.

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= #6B6B6B> <font size = 6> 6. References </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %%
# DELETE THIS CELL IN YOUR FILE

# Citations, and other references you are using.

# DO INCLUDE THE FOLLOWING CITATION FOR THIS TEMPLATE

# %% [markdown]
# [1] Munnoz, 2020. Python project template. https://github.com/iffranciscome/python-project. (2021).

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= red> TESTS (DO NOT INCLUDE IN THE FINAL NOTEBOOK) </font>

# %% [markdown]
# <hr style="border:0.02in solid red"> </hr>

# %% [markdown]
# Next are a series of tests to verify that everything is working ok. From correctly installed and loaded packages, to import other scripts, print plots with plotly

# %%
import pandas as pd
import data as dt

# %%
# -- TEST 1 : 
# verify that the script is being read
print(dt.dict_test)

# %%
# -- TEST 2 :
# verify that installed pandas module works correctly
df_dict_test = pd.DataFrame(dt.dict_test, index=[0,1])
print(df_dict_test)

# %%
# -- TEST 3 :
# verify you can use plotly and visualize plots in jupyter notebook

from plotly.offline import iplot   # print the plot inside jupyter and offline
import plotly.graph_objects as go  # functions to create plots

# example data
df = pd.DataFrame({'column_a': [1, 2, 3, 4, 5], 'column_b': [1, 2, 3, 4, 5]})
# basic plotly plot
data = [go.Bar(x=df['column_a'], y=df['column_b'])]

# instruction to view it inside jupyter
iplot(data)

# %%
# -- TEST 4 :
# verify you can use plotly and visualize plots in web browser locally

import plotly.io as pio            # to define input-output of plots
pio.renderers.default = "browser"  # to render the plot locally in your default web browser

# basic plotly plot
plot_data = go.Figure(go.Bar(x=df['column_a'], y=df['column_b']))

# instruction to view it in specified render (in this case browser)
plot_data.show()
